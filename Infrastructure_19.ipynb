# %%
from pulp import *
import pandas as pd
import numpy as np

# %%
infra_set=pd.read_excel('infra19lb.xlsx')
infra_set
# Out:
#     Unnamed: 0  supply_point_index  x_coordinate  y_coordinate  \
# 0            0                   0     50.163110     19.412014
# 1            1                   1     37.336451     58.119225
# 2            2                   2     46.709232     57.525650
# 3            3                   3     30.528626     55.379835
# 4            4                   4     51.521781     35.116755
# ..         ...                 ...           ...           ...
# 95          95                  95     45.471204     20.999414
# 96          96                  96     30.318396     33.388335
# 97          97                  97     36.218839     22.235766
# 98          98                  98     42.936915     38.122442
# 99          99                  99     19.590263      3.830284
#
#     total_parking_slots  existing_num_SCS  existing_num_FCS  Unnamed: 7  \
# 0                    23                 5                 3         NaN
# 1                    27                 4                 7         NaN
# 2                    31                 6                14         NaN
# 3                    26                 5                 5         NaN
# 4                    32                11                 6         NaN
# ..                  ...               ...               ...         ...
# 95                   24                 3                 4         NaN
# 96                   32                 5                10         NaN
# 97                   32                 4                14         NaN
# 98                   28                 7                 5         NaN
# 99                   24                 2                11         NaN
#
#     Unnamed: 8  smax18  smax19  newsmax19  Unnamed: 12  Unnamed: 13  \
# 0          NaN    2200    2689       2800          NaN          NaN
# 1          NaN    3600    4127       4200          NaN          NaN
# 2          NaN    6800    1968       2000          NaN          NaN
# 3          NaN    3000    2126       2200          NaN          NaN
# 4          NaN    4600     566        600          NaN          NaN
# ..         ...     ...     ...        ...          ...          ...
# 95         NaN    2200    4470       4600          NaN          NaN
# 96         NaN    5000    8844       9000          NaN          NaN
# 97         NaN    6400    6716       6800          NaN          NaN
# 98         NaN    3400    2796       2800          NaN          NaN
# 99         NaN    4800     962       1000          NaN          NaN
#
#     Unnamed: 14  Unnamed: 15 Unnamed: 16  Unnamed: 17
# 0           NaN          NaN         NaN          NaN
# 1           NaN          NaN         NaN          NaN
# 2           NaN          NaN         NaN          NaN
# 3           NaN          NaN         NaN          NaN
# 4           NaN          NaN         NaN          NaN
# ..          ...          ...         ...          ...
# 95          NaN          NaN         NaN          NaN
# 96          NaN          NaN         NaN          NaN
# 97          NaN          NaN         NaN          NaN
# 98          NaN          NaN         NaN          NaN
# 99          NaN          NaN         NaN          NaN
#
# [100 rows x 18 columns]

# %%
n_supply=100
smax=np.array(infra_set['newsmax19'])
smax
# Out:
# array([ 2800,  4200,  2000,  2200,   600,   800,  4200,  4400,  6000,
#         5800,  8800,  3000,  9000,  5200,  5200,  9400,  5000,  2800,
#         5400,  1400,  1600,  1400,  4800,  1200,  1600,  2600,  9600,
#         4400,  2200,  7400,  2600,  3000,  2800,  5000,  7600,  5000,
#         2400, 17200,  2000,  5200,  2800,  4800,  7200,  3200,  2400,
#         4600,  3000,  3200,  2600,  4400, 11000,  1000,  1200,  3600,
#         4000,  1000,  1600,   600,   800,   400,   600,   200,  1400,
#         1000,  4800,  9400,  7400,  5400,  3600,  8600,  2400,  2400,
#         3200,  2000,  5400,  3800,  8000,  1800,  6000,  8200,  1400,
#        11800,  4600,  3000,  1600,  4200,  6200,  3800,  3400,  3000,
#         9600,  3400, 10800,  2800,  6600,  4600,  9000,  6800,  2800,
#         1000], dtype=int64)

# %%
model = LpProblem("Supply-infra", LpMinimize)
model
# Out:
# Supply-infra:
# MINIMIZE
# None
# VARIABLES

# %%
index_numbers = [str(i) for i in range(n_supply)]
index_numbers.sort()

# %%
x_var=[]
for i in range(n_supply):
    lb=int(infra_set.iloc[i:i+1,5].values)
    lb=int(infra_set.iloc[i:i+1,5].values)
    temp=LpVariable('X_{}'.format(index_numbers[i]),cat='Integer', lowBound=lb)
    x_var.append(temp)
x_var=np.array(x_var)
x_var
# Out:
# array([X_0, X_1, X_10, X_11, X_12, X_13, X_14, X_15, X_16, X_17, X_18,
#        X_19, X_2, X_20, X_21, X_22, X_23, X_24, X_25, X_26, X_27, X_28,
#        X_29, X_3, X_30, X_31, X_32, X_33, X_34, X_35, X_36, X_37, X_38,
#        X_39, X_4, X_40, X_41, X_42, X_43, X_44, X_45, X_46, X_47, X_48,
#        X_49, X_5, X_50, X_51, X_52, X_53, X_54, X_55, X_56, X_57, X_58,
#        X_59, X_6, X_60, X_61, X_62, X_63, X_64, X_65, X_66, X_67, X_68,
#        X_69, X_7, X_70, X_71, X_72, X_73, X_74, X_75, X_76, X_77, X_78,
#        X_79, X_8, X_80, X_81, X_82, X_83, X_84, X_85, X_86, X_87, X_88,
#        X_89, X_9, X_90, X_91, X_92, X_93, X_94, X_95, X_96, X_97, X_98,
#        X_99], dtype=object)

# %%
y_var=[]
for i in range(n_supply):
    lb=int(infra_set.iloc[i:i+1,6].values)
    temp=LpVariable('y_{}'.format(index_numbers[i]),cat='Integer',lowBound=lb)
    y_var.append(temp)
y_var=np.array(y_var)
y_var
# Out:
# array([y_0, y_1, y_10, y_11, y_12, y_13, y_14, y_15, y_16, y_17, y_18,
#        y_19, y_2, y_20, y_21, y_22, y_23, y_24, y_25, y_26, y_27, y_28,
#        y_29, y_3, y_30, y_31, y_32, y_33, y_34, y_35, y_36, y_37, y_38,
#        y_39, y_4, y_40, y_41, y_42, y_43, y_44, y_45, y_46, y_47, y_48,
#        y_49, y_5, y_50, y_51, y_52, y_53, y_54, y_55, y_56, y_57, y_58,
#        y_59, y_6, y_60, y_61, y_62, y_63, y_64, y_65, y_66, y_67, y_68,
#        y_69, y_7, y_70, y_71, y_72, y_73, y_74, y_75, y_76, y_77, y_78,
#        y_79, y_8, y_80, y_81, y_82, y_83, y_84, y_85, y_86, y_87, y_88,
#        y_89, y_9, y_90, y_91, y_92, y_93, y_94, y_95, y_96, y_97, y_98,
#        y_99], dtype=object)

# %%
#Cost Equation
cost_eq=lpSum(x_var)+1.5*lpSum(y_var)
print(cost_eq)
# Out:
# X_0 + X_1 + X_10 + X_11 + X_12 + X_13 + X_14 + X_15 + X_16 + X_17 + X_18 + X_19 + X_2 + X_20 + X_21 + X_22 + X_23 + X_24 + X_25 + X_26 + X_27 + X_28 + X_29 + X_3 + X_30 + X_31 + X_32 + X_33 + X_34 + X_35 + X_36 + X_37 + X_38 + X_39 + X_4 + X_40 + X_41 + X_42 + X_43 + X_44 + X_45 + X_46 + X_47 + X_48 + X_49 + X_5 + X_50 + X_51 + X_52 + X_53 + X_54 + X_55 + X_56 + X_57 + X_58 + X_59 + X_6 + X_60 + X_61 + X_62 + X_63 + X_64 + X_65 + X_66 + X_67 + X_68 + X_69 + X_7 + X_70 + X_71 + X_72 + X_73 + X_74 + X_75 + X_76 + X_77 + X_78 + X_79 + X_8 + X_80 + X_81 + X_82 + X_83 + X_84 + X_85 + X_86 + X_87 + X_88 + X_89 + X_9 + X_90 + X_91 + X_92 + X_93 + X_94 + X_95 + X_96 + X_97 + X_98 + X_99 + 1.5*y_0 + 1.5*y_1 + 1.5*y_10 + 1.5*y_11 + 1.5*y_12 + 1.5*y_13 + 1.5*y_14 + 1.5*y_15 + 1.5*y_16 + 1.5*y_17 + 1.5*y_18 + 1.5*y_19 + 1.5*y_2 + 1.5*y_20 + 1.5*y_21 + 1.5*y_22 + 1.5*y_23 + 1.5*y_24 + 1.5*y_25 + 1.5*y_26 + 1.5*y_27 + 1.5*y_28 + 1.5*y_29 + 1.5*y_3 + 1.5*y_30 + 1.5*y_31 + 1.5*y_32 + 1.5*y_33 + 1.5*y_34 + 1.5*y_35 + 1.5*y_36 + 1.5*y_37 + 1.5*y_38 + 1.5*y_39 + 1.5*y_4 + 1.5*y_40 + 1.5*y_41 + 1.5*y_42 + 1.5*y_43 + 1.5*y_44 + 1.5*y_45 + 1.5*y_46 + 1.5*y_47 + 1.5*y_48 + 1.5*y_49 + 1.5*y_5 + 1.5*y_50 + 1.5*y_51 + 1.5*y_52 + 1.5*y_53 + 1.5*y_54 + 1.5*y_55 + 1.5*y_56 + 1.5*y_57 + 1.5*y_58 + 1.5*y_59 + 1.5*y_6 + 1.5*y_60 + 1.5*y_61 + 1.5*y_62 + 1.5*y_63 + 1.5*y_64 + 1.5*y_65 + 1.5*y_66 + 1.5*y_67 + 1.5*y_68 + 1.5*y_69 + 1.5*y_7 + 1.5*y_70 + 1.5*y_71 + 1.5*y_72 + 1.5*y_73 + 1.5*y_74 + 1.5*y_75 + 1.5*y_76 + 1.5*y_77 + 1.5*y_78 + 1.5*y_79 + 1.5*y_8 + 1.5*y_80 + 1.5*y_81 + 1.5*y_82 + 1.5*y_83 + 1.5*y_84 + 1.5*y_85 + 1.5*y_86 + 1.5*y_87 + 1.5*y_88 + 1.5*y_89 + 1.5*y_9 + 1.5*y_90 + 1.5*y_91 + 1.5*y_92 + 1.5*y_93 + 1.5*y_94 + 1.5*y_95 + 1.5*y_96 + 1.5*y_97 + 1.5*y_98 + 1.5*y_99

# %%
tot_p=np.array(infra_set['total_parking_slots'])
tot_p
# Out:
# array([23, 27, 31, 26, 32, 28, 25, 32, 30, 21, 14, 21, 22, 28, 30, 24, 13,
#         7, 26, 28, 23, 28, 20, 24, 20, 28, 31, 29, 32, 28, 19, 33, 34, 29,
#        19,  9, 30, 13, 20, 29, 24, 21, 30, 33, 18, 31, 28, 21, 28, 30, 30,
#        12, 27, 34, 32, 16, 29, 17, 20, 23, 10, 11, 31, 18, 20, 33, 14, 33,
#        27, 30, 29, 35, 24, 27, 11, 33, 10, 29, 36, 30, 25, 35, 22, 26,  8,
#        26, 27, 24, 17, 31, 26, 36, 19, 27, 30, 24, 32, 32, 28, 24],
#       dtype=int64)

# %%
model += cost_eq
model
# Out:
# Supply-infra:
# MINIMIZE
# 1*X_0 + 1*X_1 + 1*X_10 + 1*X_11 + 1*X_12 + 1*X_13 + 1*X_14 + 1*X_15 + 1*X_16 + 1*X_17 + 1*X_18 + 1*X_19 + 1*X_2 + 1*X_20 + 1*X_21 + 1*X_22 + 1*X_23 + 1*X_24 + 1*X_25 + 1*X_26 + 1*X_27 + 1*X_28 + 1*X_29 + 1*X_3 + 1*X_30 + 1*X_31 + 1*X_32 + 1*X_33 + 1*X_34 + 1*X_35 + 1*X_36 + 1*X_37 + 1*X_38 + 1*X_39 + 1*X_4 + 1*X_40 + 1*X_41 + 1*X_42 + 1*X_43 + 1*X_44 + 1*X_45 + 1*X_46 + 1*X_47 + 1*X_48 + 1*X_49 + 1*X_5 + 1*X_50 + 1*X_51 + 1*X_52 + 1*X_53 + 1*X_54 + 1*X_55 + 1*X_56 + 1*X_57 + 1*X_58 + 1*X_59 + 1*X_6 + 1*X_60 + 1*X_61 + 1*X_62 + 1*X_63 + 1*X_64 + 1*X_65 + 1*X_66 + 1*X_67 + 1*X_68 + 1*X_69 + 1*X_7 + 1*X_70 + 1*X_71 + 1*X_72 + 1*X_73 + 1*X_74 + 1*X_75 + 1*X_76 + 1*X_77 + 1*X_78 + 1*X_79 + 1*X_8 + 1*X_80 + 1*X_81 + 1*X_82 + 1*X_83 + 1*X_84 + 1*X_85 + 1*X_86 + 1*X_87 + 1*X_88 + 1*X_89 + 1*X_9 + 1*X_90 + 1*X_91 + 1*X_92 + 1*X_93 + 1*X_94 + 1*X_95 + 1*X_96 + 1*X_97 + 1*X_98 + 1*X_99 + 1.5*y_0 + 1.5*y_1 + 1.5*y_10 + 1.5*y_11 + 1.5*y_12 + 1.5*y_13 + 1.5*y_14 + 1.5*y_15 + 1.5*y_16 + 1.5*y_17 + 1.5*y_18 + 1.5*y_19 + 1.5*y_2 + 1.5*y_20 + 1.5*y_21 + 1.5*y_22 + 1.5*y_23 + 1.5*y_24 + 1.5*y_25 + 1.5*y_26 + 1.5*y_27 + 1.5*y_28 + 1.5*y_29 + 1.5*y_3 + 1.5*y_30 + 1.5*y_31 + 1.5*y_32 + 1.5*y_33 + 1.5*y_34 + 1.5*y_35 + 1.5*y_36 + 1.5*y_37 + 1.5*y_38 + 1.5*y_39 + 1.5*y_4 + 1.5*y_40 + 1.5*y_41 + 1.5*y_42 + 1.5*y_43 + 1.5*y_44 + 1.5*y_45 + 1.5*y_46 + 1.5*y_47 + 1.5*y_48 + 1.5*y_49 + 1.5*y_5 + 1.5*y_50 + 1.5*y_51 + 1.5*y_52 + 1.5*y_53 + 1.5*y_54 + 1.5*y_55 + 1.5*y_56 + 1.5*y_57 + 1.5*y_58 + 1.5*y_59 + 1.5*y_6 + 1.5*y_60 + 1.5*y_61 + 1.5*y_62 + 1.5*y_63 + 1.5*y_64 + 1.5*y_65 + 1.5*y_66 + 1.5*y_67 + 1.5*y_68 + 1.5*y_69 + 1.5*y_7 + 1.5*y_70 + 1.5*y_71 + 1.5*y_72 + 1.5*y_73 + 1.5*y_74 + 1.5*y_75 + 1.5*y_76 + 1.5*y_77 + 1.5*y_78 + 1.5*y_79 + 1.5*y_8 + 1.5*y_80 + 1.5*y_81 + 1.5*y_82 + 1.5*y_83 + 1.5*y_84 + 1.5*y_85 + 1.5*y_86 + 1.5*y_87 + 1.5*y_88 + 1.5*y_89 + 1.5*y_9 + 1.5*y_90 + 1.5*y_91 + 1.5*y_92 + 1.5*y_93 + 1.5*y_94 + 1.5*y_95 + 1.5*y_96 + 1.5*y_97 + 1.5*y_98 + 1.5*y_99 + 0.0
# VARIABLES
# 5 <= X_0 Integer
# 4 <= X_1 Integer
# 6 <= X_10 Integer
# 5 <= X_11 Integer
# 11 <= X_12 Integer
# 9 <= X_13 Integer
# 9 <= X_14 Integer
# 6 <= X_15 Integer
# 9 <= X_16 Integer
# 6 <= X_17 Integer
# 6 <= X_18 Integer
# 9 <= X_19 Integer
# 5 <= X_2 Integer
# 7 <= X_20 Integer
# 4 <= X_21 Integer
# 5 <= X_22 Integer
# 4 <= X_23 Integer
# 4 <= X_24 Integer
# 1 <= X_25 Integer
# 6 <= X_26 Integer
# 6 <= X_27 Integer
# 10 <= X_28 Integer
# 5 <= X_29 Integer
# 4 <= X_3 Integer
# 7 <= X_30 Integer
# 6 <= X_31 Integer
# 7 <= X_32 Integer
# 8 <= X_33 Integer
# 11 <= X_34 Integer
# 6 <= X_35 Integer
# 5 <= X_36 Integer
# 6 <= X_37 Integer
# 7 <= X_38 Integer
# 6 <= X_39 Integer
# 5 <= X_4 Integer
# 2 <= X_40 Integer
# 4 <= X_41 Integer
# 4 <= X_42 Integer
# 5 <= X_43 Integer
# 6 <= X_44 Integer
# 7 <= X_45 Integer
# 3 <= X_46 Integer
# 11 <= X_47 Integer
# 6 <= X_48 Integer
# 1 <= X_49 Integer
# 7 <= X_5 Integer
# 3 <= X_50 Integer
# 5 <= X_51 Integer
# 7 <= X_52 Integer
# 7 <= X_53 Integer
# 7 <= X_54 Integer
# 4 <= X_55 Integer
# 3 <= X_56 Integer
# 2 <= X_57 Integer
# 3 <= X_58 Integer
# 3 <= X_59 Integer
# 6 <= X_6 Integer
# 5 <= X_60 Integer
# 8 <= X_61 Integer
# 7 <= X_62 Integer
# 2 <= X_63 Integer
# 3 <= X_64 Integer
# 5 <= X_65 Integer
# 6 <= X_66 Integer
# 3 <= X_67 Integer
# 4 <= X_68 Integer
# 2 <= X_69 Integer
# 8 <= X_7 Integer
# 6 <= X_70 Integer
# 5 <= X_71 Integer
# 2 <= X_72 Integer
# 12 <= X_73 Integer
# 10 <= X_74 Integer
# 5 <= X_75 Integer
# 3 <= X_76 Integer
# 3 <= X_77 Integer
# 4 <= X_78 Integer
# 7 <= X_79 Integer
# 11 <= X_8 Integer
# 7 <= X_80 Integer
# 8 <= X_81 Integer
# 7 <= X_82 Integer
# 6 <= X_83 Integer
# 7 <= X_84 Integer
# 5 <= X_85 Integer
# 9 <= X_86 Integer
# 6 <= X_87 Integer
# 5 <= X_88 Integer
# 4 <= X_89 Integer
# 3 <= X_9 Integer
# 11 <= X_90 Integer
# 3 <= X_91 Integer
# 6 <= X_92 Integer
# 8 <= X_93 Integer
# 7 <= X_94 Integer
# 3 <= X_95 Integer
# 5 <= X_96 Integer
# 4 <= X_97 Integer
# 7 <= X_98 Integer
# 2 <= X_99 Integer
# 3 <= y_0 Integer
# 7 <= y_1 Integer
# 14 <= y_10 Integer
# 5 <= y_11 Integer
# 6 <= y_12 Integer
# 6 <= y_13 Integer
# 8 <= y_14 Integer
# 6 <= y_15 Integer
# 1 <= y_16 Integer
# 5 <= y_17 Integer
# 0 <= y_18 Integer
# 4 <= y_19 Integer
# 5 <= y_2 Integer
# 5 <= y_20 Integer
# 12 <= y_21 Integer
# 6 <= y_22 Integer
# 2 <= y_23 Integer
# 0 <= y_24 Integer
# 8 <= y_25 Integer
# 8 <= y_26 Integer
# 8 <= y_27 Integer
# 8 <= y_28 Integer
# 4 <= y_29 Integer
# 7 <= y_3 Integer
# 3 <= y_30 Integer
# 10 <= y_31 Integer
# 11 <= y_32 Integer
# 4 <= y_33 Integer
# 6 <= y_34 Integer
# 3 <= y_35 Integer
# 2 <= y_36 Integer
# 9 <= y_37 Integer
# 10 <= y_38 Integer
# 7 <= y_39 Integer
# 1 <= y_4 Integer
# 1 <= y_40 Integer
# 9 <= y_41 Integer
# 4 <= y_42 Integer
# 4 <= y_43 Integer
# 6 <= y_44 Integer
# 6 <= y_45 Integer
# 4 <= y_46 Integer
# 4 <= y_47 Integer
# 10 <= y_48 Integer
# 6 <= y_49 Integer
# 6 <= y_5 Integer
# 8 <= y_50 Integer
# 1 <= y_51 Integer
# 10 <= y_52 Integer
# 13 <= y_53 Integer
# 8 <= y_54 Integer
# 1 <= y_55 Integer
# 7 <= y_56 Integer
# 16 <= y_57 Integer
# 10 <= y_58 Integer
# 1 <= y_59 Integer
# 9 <= y_6 Integer
# 1 <= y_60 Integer
# 3 <= y_61 Integer
# 3 <= y_62 Integer
# 3 <= y_63 Integer
# 0 <= y_64 Integer
# 10 <= y_65 Integer
# 5 <= y_66 Integer
# 2 <= y_67 Integer
# 11 <= y_68 Integer
# 2 <= y_69 Integer
# 13 <= y_7 Integer
# 9 <= y_70 Integer
# 6 <= y_71 Integer
# 8 <= y_72 Integer
# 7 <= y_73 Integer
# 1 <= y_74 Integer
# 4 <= y_75 Integer
# 1 <= y_76 Integer
# 15 <= y_77 Integer
# 2 <= y_78 Integer
# 11 <= y_79 Integer
# 8 <= y_8 Integer
# 6 <= y_80 Integer
# 9 <= y_81 Integer
# 7 <= y_82 Integer
# 7 <= y_83 Integer
# 6 <= y_84 Integer
# 2 <= y_85 Integer
# 7 <= y_86 Integer
# 7 <= y_87 Integer
# 5 <= y_88 Integer
# 1 <= y_89 Integer
# 10 <= y_9 Integer
# 5 <= y_90 Integer
# 12 <= y_91 Integer
# 3 <= y_92 Integer
# 6 <= y_93 Integer
# 9 <= y_94 Integer
# 4 <= y_95 Integer
# 10 <= y_96 Integer
# 14 <= y_97 Integer
# 5 <= y_98 Integer
# 11 <= y_99 Integer

# %% [markdown]
# for i in range(n_supply):
#     lb=int(infra_set.iloc[i:i+1,5].values)
#     constraint= x_var[i]>=lb
#     model+=constraint
# for i in range(n_supply):
#     lb=int(infra_set.iloc[i:i+1,6].values)
#     constraint= y_var[i]>=lb
#     model+=constraint

# %%
model
# Out:
# Supply-infra:
# MINIMIZE
# 1*X_0 + 1*X_1 + 1*X_10 + 1*X_11 + 1*X_12 + 1*X_13 + 1*X_14 + 1*X_15 + 1*X_16 + 1*X_17 + 1*X_18 + 1*X_19 + 1*X_2 + 1*X_20 + 1*X_21 + 1*X_22 + 1*X_23 + 1*X_24 + 1*X_25 + 1*X_26 + 1*X_27 + 1*X_28 + 1*X_29 + 1*X_3 + 1*X_30 + 1*X_31 + 1*X_32 + 1*X_33 + 1*X_34 + 1*X_35 + 1*X_36 + 1*X_37 + 1*X_38 + 1*X_39 + 1*X_4 + 1*X_40 + 1*X_41 + 1*X_42 + 1*X_43 + 1*X_44 + 1*X_45 + 1*X_46 + 1*X_47 + 1*X_48 + 1*X_49 + 1*X_5 + 1*X_50 + 1*X_51 + 1*X_52 + 1*X_53 + 1*X_54 + 1*X_55 + 1*X_56 + 1*X_57 + 1*X_58 + 1*X_59 + 1*X_6 + 1*X_60 + 1*X_61 + 1*X_62 + 1*X_63 + 1*X_64 + 1*X_65 + 1*X_66 + 1*X_67 + 1*X_68 + 1*X_69 + 1*X_7 + 1*X_70 + 1*X_71 + 1*X_72 + 1*X_73 + 1*X_74 + 1*X_75 + 1*X_76 + 1*X_77 + 1*X_78 + 1*X_79 + 1*X_8 + 1*X_80 + 1*X_81 + 1*X_82 + 1*X_83 + 1*X_84 + 1*X_85 + 1*X_86 + 1*X_87 + 1*X_88 + 1*X_89 + 1*X_9 + 1*X_90 + 1*X_91 + 1*X_92 + 1*X_93 + 1*X_94 + 1*X_95 + 1*X_96 + 1*X_97 + 1*X_98 + 1*X_99 + 1.5*y_0 + 1.5*y_1 + 1.5*y_10 + 1.5*y_11 + 1.5*y_12 + 1.5*y_13 + 1.5*y_14 + 1.5*y_15 + 1.5*y_16 + 1.5*y_17 + 1.5*y_18 + 1.5*y_19 + 1.5*y_2 + 1.5*y_20 + 1.5*y_21 + 1.5*y_22 + 1.5*y_23 + 1.5*y_24 + 1.5*y_25 + 1.5*y_26 + 1.5*y_27 + 1.5*y_28 + 1.5*y_29 + 1.5*y_3 + 1.5*y_30 + 1.5*y_31 + 1.5*y_32 + 1.5*y_33 + 1.5*y_34 + 1.5*y_35 + 1.5*y_36 + 1.5*y_37 + 1.5*y_38 + 1.5*y_39 + 1.5*y_4 + 1.5*y_40 + 1.5*y_41 + 1.5*y_42 + 1.5*y_43 + 1.5*y_44 + 1.5*y_45 + 1.5*y_46 + 1.5*y_47 + 1.5*y_48 + 1.5*y_49 + 1.5*y_5 + 1.5*y_50 + 1.5*y_51 + 1.5*y_52 + 1.5*y_53 + 1.5*y_54 + 1.5*y_55 + 1.5*y_56 + 1.5*y_57 + 1.5*y_58 + 1.5*y_59 + 1.5*y_6 + 1.5*y_60 + 1.5*y_61 + 1.5*y_62 + 1.5*y_63 + 1.5*y_64 + 1.5*y_65 + 1.5*y_66 + 1.5*y_67 + 1.5*y_68 + 1.5*y_69 + 1.5*y_7 + 1.5*y_70 + 1.5*y_71 + 1.5*y_72 + 1.5*y_73 + 1.5*y_74 + 1.5*y_75 + 1.5*y_76 + 1.5*y_77 + 1.5*y_78 + 1.5*y_79 + 1.5*y_8 + 1.5*y_80 + 1.5*y_81 + 1.5*y_82 + 1.5*y_83 + 1.5*y_84 + 1.5*y_85 + 1.5*y_86 + 1.5*y_87 + 1.5*y_88 + 1.5*y_89 + 1.5*y_9 + 1.5*y_90 + 1.5*y_91 + 1.5*y_92 + 1.5*y_93 + 1.5*y_94 + 1.5*y_95 + 1.5*y_96 + 1.5*y_97 + 1.5*y_98 + 1.5*y_99 + 0.0
# SUBJECT TO
# _C1: X_0 >= 5
#
# _C2: X_1 >= 4
#
# _C3: X_10 >= 6
#
# _C4: X_11 >= 5
#
# _C5: X_12 >= 11
#
# _C6: X_13 >= 9
#
# _C7: X_14 >= 9
#
# _C8: X_15 >= 6
#
# _C9: X_16 >= 9
#
# _C10: X_17 >= 6
#
# _C11: X_18 >= 6
#
# _C12: X_19 >= 9
#
# _C13: X_2 >= 5
#
# _C14: X_20 >= 7
#
# _C15: X_21 >= 4
#
# _C16: X_22 >= 5
#
# _C17: X_23 >= 4
#
# _C18: X_24 >= 4
#
# _C19: X_25 >= 1
#
# _C20: X_26 >= 6
#
# _C21: X_27 >= 6
#
# _C22: X_28 >= 10
#
# _C23: X_29 >= 5
#
# _C24: X_3 >= 4
#
# _C25: X_30 >= 7
#
# _C26: X_31 >= 6
#
# _C27: X_32 >= 7
#
# _C28: X_33 >= 8
#
# _C29: X_34 >= 11
#
# _C30: X_35 >= 6
#
# _C31: X_36 >= 5
#
# _C32: X_37 >= 6
#
# _C33: X_38 >= 7
#
# _C34: X_39 >= 6
#
# _C35: X_4 >= 5
#
# _C36: X_40 >= 2
#
# _C37: X_41 >= 4
#
# _C38: X_42 >= 4
#
# _C39: X_43 >= 5
#
# _C40: X_44 >= 6
#
# _C41: X_45 >= 7
#
# _C42: X_46 >= 3
#
# _C43: X_47 >= 11
#
# _C44: X_48 >= 6
#
# _C45: X_49 >= 1
#
# _C46: X_5 >= 7
#
# _C47: X_50 >= 3
#
# _C48: X_51 >= 5
#
# _C49: X_52 >= 7
#
# _C50: X_53 >= 7
#
# _C51: X_54 >= 7
#
# _C52: X_55 >= 4
#
# _C53: X_56 >= 3
#
# _C54: X_57 >= 2
#
# _C55: X_58 >= 3
#
# _C56: X_59 >= 3
#
# _C57: X_6 >= 6
#
# _C58: X_60 >= 5
#
# _C59: X_61 >= 8
#
# _C60: X_62 >= 7
#
# _C61: X_63 >= 2
#
# _C62: X_64 >= 3
#
# _C63: X_65 >= 5
#
# _C64: X_66 >= 6
#
# _C65: X_67 >= 3
#
# _C66: X_68 >= 4
#
# _C67: X_69 >= 2
#
# _C68: X_7 >= 8
#
# _C69: X_70 >= 6
#
# _C70: X_71 >= 5
#
# _C71: X_72 >= 2
#
# _C72: X_73 >= 12
#
# _C73: X_74 >= 10
#
# _C74: X_75 >= 5
#
# _C75: X_76 >= 3
#
# _C76: X_77 >= 3
#
# _C77: X_78 >= 4
#
# _C78: X_79 >= 7
#
# _C79: X_8 >= 11
#
# _C80: X_80 >= 7
#
# _C81: X_81 >= 8
#
# _C82: X_82 >= 7
#
# _C83: X_83 >= 6
#
# _C84: X_84 >= 7
#
# _C85: X_85 >= 5
#
# _C86: X_86 >= 9
#
# _C87: X_87 >= 6
#
# _C88: X_88 >= 5
#
# _C89: X_89 >= 4
#
# _C90: X_9 >= 3
#
# _C91: X_90 >= 11
#
# _C92: X_91 >= 3
#
# _C93: X_92 >= 6
#
# _C94: X_93 >= 8
#
# _C95: X_94 >= 7
#
# _C96: X_95 >= 3
#
# _C97: X_96 >= 5
#
# _C98: X_97 >= 4
#
# _C99: X_98 >= 7
#
# _C100: X_99 >= 2
#
# _C101: y_0 >= 3
#
# _C102: y_1 >= 7
#
# _C103: y_10 >= 14
#
# _C104: y_11 >= 5
#
# _C105: y_12 >= 6
#
# _C106: y_13 >= 6
#
# _C107: y_14 >= 8
#
# _C108: y_15 >= 6
#
# _C109: y_16 >= 1
#
# _C110: y_17 >= 5
#
# _C111: y_18 >= 0
#
# _C112: y_19 >= 4
#
# _C113: y_2 >= 5
#
# _C114: y_20 >= 5
#
# _C115: y_21 >= 12
#
# _C116: y_22 >= 6
#
# _C117: y_23 >= 2
#
# _C118: y_24 >= 0
#
# _C119: y_25 >= 8
#
# _C120: y_26 >= 8
#
# _C121: y_27 >= 8
#
# _C122: y_28 >= 8
#
# _C123: y_29 >= 4
#
# _C124: y_3 >= 7
#
# _C125: y_30 >= 3
#
# _C126: y_31 >= 10
#
# _C127: y_32 >= 11
#
# _C128: y_33 >= 4
#
# _C129: y_34 >= 6
#
# _C130: y_35 >= 3
#
# _C131: y_36 >= 2
#
# _C132: y_37 >= 9
#
# _C133: y_38 >= 10
#
# _C134: y_39 >= 7
#
# _C135: y_4 >= 1
#
# _C136: y_40 >= 1
#
# _C137: y_41 >= 9
#
# _C138: y_42 >= 4
#
# _C139: y_43 >= 4
#
# _C140: y_44 >= 6
#
# _C141: y_45 >= 6
#
# _C142: y_46 >= 4
#
# _C143: y_47 >= 4
#
# _C144: y_48 >= 10
#
# _C145: y_49 >= 6
#
# _C146: y_5 >= 6
#
# _C147: y_50 >= 8
#
# _C148: y_51 >= 1
#
# _C149: y_52 >= 10
#
# _C150: y_53 >= 13
#
# _C151: y_54 >= 8
#
# _C152: y_55 >= 1
#
# _C153: y_56 >= 7
#
# _C154: y_57 >= 16
#
# _C155: y_58 >= 10
#
# _C156: y_59 >= 1
#
# _C157: y_6 >= 9
#
# _C158: y_60 >= 1
#
# _C159: y_61 >= 3
#
# _C160: y_62 >= 3
#
# _C161: y_63 >= 3
#
# _C162: y_64 >= 0
#
# _C163: y_65 >= 10
#
# _C164: y_66 >= 5
#
# _C165: y_67 >= 2
#
# _C166: y_68 >= 11
#
# _C167: y_69 >= 2
#
# _C168: y_7 >= 13
#
# _C169: y_70 >= 9
#
# _C170: y_71 >= 6
#
# _C171: y_72 >= 8
#
# _C172: y_73 >= 7
#
# _C173: y_74 >= 1
#
# _C174: y_75 >= 4
#
# _C175: y_76 >= 1
#
# _C176: y_77 >= 15
#
# _C177: y_78 >= 2
#
# _C178: y_79 >= 11
#
# _C179: y_8 >= 8
#
# _C180: y_80 >= 6
#
# _C181: y_81 >= 9
#
# _C182: y_82 >= 7
#
# _C183: y_83 >= 7
#
# _C184: y_84 >= 6
#
# _C185: y_85 >= 2
#
# _C186: y_86 >= 7
#
# _C187: y_87 >= 7
#
# _C188: y_88 >= 5
#
# _C189: y_89 >= 1
#
# _C190: y_9 >= 10
#
# _C191: y_90 >= 5
#
# _C192: y_91 >= 12
#
# _C193: y_92 >= 3
#
# _C194: y_93 >= 6
#
# _C195: y_94 >= 9
#
# _C196: y_95 >= 4
#
# _C197: y_96 >= 10
#
# _C198: y_97 >= 14
#
# _C199: y_98 >= 5
#
# _C200: y_99 >= 11
#
# VARIABLES
# 5 <= X_0 Integer
# 4 <= X_1 Integer
# 6 <= X_10 Integer
# 5 <= X_11 Integer
# 11 <= X_12 Integer
# 9 <= X_13 Integer
# 9 <= X_14 Integer
# 6 <= X_15 Integer
# 9 <= X_16 Integer
# 6 <= X_17 Integer
# 6 <= X_18 Integer
# 9 <= X_19 Integer
# 5 <= X_2 Integer
# 7 <= X_20 Integer
# 4 <= X_21 Integer
# 5 <= X_22 Integer
# 4 <= X_23 Integer
# 4 <= X_24 Integer
# 1 <= X_25 Integer
# 6 <= X_26 Integer
# 6 <= X_27 Integer
# 10 <= X_28 Integer
# 5 <= X_29 Integer
# 4 <= X_3 Integer
# 7 <= X_30 Integer
# 6 <= X_31 Integer
# 7 <= X_32 Integer
# 8 <= X_33 Integer
# 11 <= X_34 Integer
# 6 <= X_35 Integer
# 5 <= X_36 Integer
# 6 <= X_37 Integer
# 7 <= X_38 Integer
# 6 <= X_39 Integer
# 5 <= X_4 Integer
# 2 <= X_40 Integer
# 4 <= X_41 Integer
# 4 <= X_42 Integer
# 5 <= X_43 Integer
# 6 <= X_44 Integer
# 7 <= X_45 Integer
# 3 <= X_46 Integer
# 11 <= X_47 Integer
# 6 <= X_48 Integer
# 1 <= X_49 Integer
# 7 <= X_5 Integer
# 3 <= X_50 Integer
# 5 <= X_51 Integer
# 7 <= X_52 Integer
# 7 <= X_53 Integer
# 7 <= X_54 Integer
# 4 <= X_55 Integer
# 3 <= X_56 Integer
# 2 <= X_57 Integer
# 3 <= X_58 Integer
# 3 <= X_59 Integer
# 6 <= X_6 Integer
# 5 <= X_60 Integer
# 8 <= X_61 Integer
# 7 <= X_62 Integer
# 2 <= X_63 Integer
# 3 <= X_64 Integer
# 5 <= X_65 Integer
# 6 <= X_66 Integer
# 3 <= X_67 Integer
# 4 <= X_68 Integer
# 2 <= X_69 Integer
# 8 <= X_7 Integer
# 6 <= X_70 Integer
# 5 <= X_71 Integer
# 2 <= X_72 Integer
# 12 <= X_73 Integer
# 10 <= X_74 Integer
# 5 <= X_75 Integer
# 3 <= X_76 Integer
# 3 <= X_77 Integer
# 4 <= X_78 Integer
# 7 <= X_79 Integer
# 11 <= X_8 Integer
# 7 <= X_80 Integer
# 8 <= X_81 Integer
# 7 <= X_82 Integer
# 6 <= X_83 Integer
# 7 <= X_84 Integer
# 5 <= X_85 Integer
# 9 <= X_86 Integer
# 6 <= X_87 Integer
# 5 <= X_88 Integer
# 4 <= X_89 Integer
# 3 <= X_9 Integer
# 11 <= X_90 Integer
# 3 <= X_91 Integer
# 6 <= X_92 Integer
# 8 <= X_93 Integer
# 7 <= X_94 Integer
# 3 <= X_95 Integer
# 5 <= X_96 Integer
# 4 <= X_97 Integer
# 7 <= X_98 Integer
# 2 <= X_99 Integer
# 3 <= y_0 Integer
# 7 <= y_1 Integer
# 14 <= y_10 Integer
# 5 <= y_11 Integer
# 6 <= y_12 Integer
# 6 <= y_13 Integer
# 8 <= y_14 Integer
# 6 <= y_15 Integer
# 1 <= y_16 Integer
# 5 <= y_17 Integer
# 0 <= y_18 Integer
# 4 <= y_19 Integer
# 5 <= y_2 Integer
# 5 <= y_20 Integer
# 12 <= y_21 Integer
# 6 <= y_22 Integer
# 2 <= y_23 Integer
# 0 <= y_24 Integer
# 8 <= y_25 Integer
# 8 <= y_26 Integer
# 8 <= y_27 Integer
# 8 <= y_28 Integer
# 4 <= y_29 Integer
# 7 <= y_3 Integer
# 3 <= y_30 Integer
# 10 <= y_31 Integer
# 11 <= y_32 Integer
# 4 <= y_33 Integer
# 6 <= y_34 Integer
# 3 <= y_35 Integer
# 2 <= y_36 Integer
# 9 <= y_37 Integer
# 10 <= y_38 Integer
# 7 <= y_39 Integer
# 1 <= y_4 Integer
# 1 <= y_40 Integer
# 9 <= y_41 Integer
# 4 <= y_42 Integer
# 4 <= y_43 Integer
# 6 <= y_44 Integer
# 6 <= y_45 Integer
# 4 <= y_46 Integer
# 4 <= y_47 Integer
# 10 <= y_48 Integer
# 6 <= y_49 Integer
# 6 <= y_5 Integer
# 8 <= y_50 Integer
# 1 <= y_51 Integer
# 10 <= y_52 Integer
# 13 <= y_53 Integer
# 8 <= y_54 Integer
# 1 <= y_55 Integer
# 7 <= y_56 Integer
# 16 <= y_57 Integer
# 10 <= y_58 Integer
# 1 <= y_59 Integer
# 9 <= y_6 Integer
# 1 <= y_60 Integer
# 3 <= y_61 Integer
# 3 <= y_62 Integer
# 3 <= y_63 Integer
# 0 <= y_64 Integer
# 10 <= y_65 Integer
# 5 <= y_66 Integer
# 2 <= y_67 Integer
# 11 <= y_68 Integer
# 2 <= y_69 Integer
# 13 <= y_7 Integer
# 9 <= y_70 Integer
# 6 <= y_71 Integer
# 8 <= y_72 Integer
# 7 <= y_73 Integer
# 1 <= y_74 Integer
# 4 <= y_75 Integer
# 1 <= y_76 Integer
# 15 <= y_77 Integer
# 2 <= y_78 Integer
# 11 <= y_79 Integer
# 8 <= y_8 Integer
# 6 <= y_80 Integer
# 9 <= y_81 Integer
# 7 <= y_82 Integer
# 7 <= y_83 Integer
# 6 <= y_84 Integer
# 2 <= y_85 Integer
# 7 <= y_86 Integer
# 7 <= y_87 Integer
# 5 <= y_88 Integer
# 1 <= y_89 Integer
# 10 <= y_9 Integer
# 5 <= y_90 Integer
# 12 <= y_91 Integer
# 3 <= y_92 Integer
# 6 <= y_93 Integer
# 9 <= y_94 Integer
# 4 <= y_95 Integer
# 10 <= y_96 Integer
# 14 <= y_97 Integer
# 5 <= y_98 Integer
# 11 <= y_99 Integer

# %%
#Supply Constraint
for i in range(n_supply):
    constraint = (x_var[i]*200)+(y_var[i]*400) == int(infra_set.iloc[i:i+1,11].values)
    print(constraint)
    model += constraint
# Out:
# 200*X_0 + 400*y_0 = 2800
# 200*X_1 + 400*y_1 = 4200
# 200*X_10 + 400*y_10 = 2000
# 200*X_11 + 400*y_11 = 2200
# 200*X_12 + 400*y_12 = 600
# 200*X_13 + 400*y_13 = 800
# 200*X_14 + 400*y_14 = 4200
# 200*X_15 + 400*y_15 = 4400
# 200*X_16 + 400*y_16 = 6000
# 200*X_17 + 400*y_17 = 5800
# 200*X_18 + 400*y_18 = 8800
# 200*X_19 + 400*y_19 = 3000
# 200*X_2 + 400*y_2 = 9000
# 200*X_20 + 400*y_20 = 5200
# 200*X_21 + 400*y_21 = 5200
# 200*X_22 + 400*y_22 = 9400
# 200*X_23 + 400*y_23 = 5000
# 200*X_24 + 400*y_24 = 2800
# 200*X_25 + 400*y_25 = 5400
# 200*X_26 + 400*y_26 = 1400
# 200*X_27 + 400*y_27 = 1600
# 200*X_28 + 400*y_28 = 1400
# 200*X_29 + 400*y_29 = 4800
# 200*X_3 + 400*y_3 = 1200
# 200*X_30 + 400*y_30 = 1600
# 200*X_31 + 400*y_31 = 2600
# 200*X_32 + 400*y_32 = 9600
# 200*X_33 + 400*y_33 = 4400
# 200*X_34 + 400*y_34 = 2200
# 200*X_35 + 400*y_35 = 7400
# 200*X_36 + 400*y_36 = 2600
# 200*X_37 + 400*y_37 = 3000
# 200*X_38 + 400*y_38 = 2800
# 200*X_39 + 400*y_39 = 5000
# 200*X_4 + 400*y_4 = 7600
# 200*X_40 + 400*y_40 = 5000
# 200*X_41 + 400*y_41 = 2400
# 200*X_42 + 400*y_42 = 17200
# 200*X_43 + 400*y_43 = 2000
# 200*X_44 + 400*y_44 = 5200
# 200*X_45 + 400*y_45 = 2800
# 200*X_46 + 400*y_46 = 4800
# 200*X_47 + 400*y_47 = 7200
# 200*X_48 + 400*y_48 = 3200
# 200*X_49 + 400*y_49 = 2400
# 200*X_5 + 400*y_5 = 4600
# 200*X_50 + 400*y_50 = 3000
# 200*X_51 + 400*y_51 = 3200
# 200*X_52 + 400*y_52 = 2600
# 200*X_53 + 400*y_53 = 4400
# 200*X_54 + 400*y_54 = 11000
# 200*X_55 + 400*y_55 = 1000
# 200*X_56 + 400*y_56 = 1200
# 200*X_57 + 400*y_57 = 3600
# 200*X_58 + 400*y_58 = 4000
# 200*X_59 + 400*y_59 = 1000
# 200*X_6 + 400*y_6 = 1600
# 200*X_60 + 400*y_60 = 600
# 200*X_61 + 400*y_61 = 800
# 200*X_62 + 400*y_62 = 400
# 200*X_63 + 400*y_63 = 600
# 200*X_64 + 400*y_64 = 200
# 200*X_65 + 400*y_65 = 1400
# 200*X_66 + 400*y_66 = 1000
# 200*X_67 + 400*y_67 = 4800
# 200*X_68 + 400*y_68 = 9400
# 200*X_69 + 400*y_69 = 7400
# 200*X_7 + 400*y_7 = 5400
# 200*X_70 + 400*y_70 = 3600
# 200*X_71 + 400*y_71 = 8600
# 200*X_72 + 400*y_72 = 2400
# 200*X_73 + 400*y_73 = 2400
# 200*X_74 + 400*y_74 = 3200
# 200*X_75 + 400*y_75 = 2000
# 200*X_76 + 400*y_76 = 5400
# 200*X_77 + 400*y_77 = 3800
# 200*X_78 + 400*y_78 = 8000
# 200*X_79 + 400*y_79 = 1800
# 200*X_8 + 400*y_8 = 6000
# 200*X_80 + 400*y_80 = 8200
# 200*X_81 + 400*y_81 = 1400
# 200*X_82 + 400*y_82 = 11800
# 200*X_83 + 400*y_83 = 4600
# 200*X_84 + 400*y_84 = 3000
# 200*X_85 + 400*y_85 = 1600
# 200*X_86 + 400*y_86 = 4200
# 200*X_87 + 400*y_87 = 6200
# 200*X_88 + 400*y_88 = 3800
# 200*X_89 + 400*y_89 = 3400
# 200*X_9 + 400*y_9 = 3000
# 200*X_90 + 400*y_90 = 9600
# 200*X_91 + 400*y_91 = 3400
# 200*X_92 + 400*y_92 = 10800
# 200*X_93 + 400*y_93 = 2800
# 200*X_94 + 400*y_94 = 6600
# 200*X_95 + 400*y_95 = 4600
# 200*X_96 + 400*y_96 = 9000
# 200*X_97 + 400*y_97 = 6800
# 200*X_98 + 400*y_98 = 2800
# 200*X_99 + 400*y_99 = 1000

# %%
#Parking Constraint
for i in range(n_supply):
    constraint = x_var[i]+y_var[i] <= tot_p[i]
    print(constraint)
    model += constraint
# Out:
# X_0 + y_0 <= 23
# X_1 + y_1 <= 27
# X_10 + y_10 <= 31
# X_11 + y_11 <= 26
# X_12 + y_12 <= 32
# X_13 + y_13 <= 28
# X_14 + y_14 <= 25
# X_15 + y_15 <= 32
# X_16 + y_16 <= 30
# X_17 + y_17 <= 21
# X_18 + y_18 <= 14
# X_19 + y_19 <= 21
# X_2 + y_2 <= 22
# X_20 + y_20 <= 28
# X_21 + y_21 <= 30
# X_22 + y_22 <= 24
# X_23 + y_23 <= 13
# X_24 + y_24 <= 7
# X_25 + y_25 <= 26
# X_26 + y_26 <= 28
# X_27 + y_27 <= 23
# X_28 + y_28 <= 28
# X_29 + y_29 <= 20
# X_3 + y_3 <= 24
# X_30 + y_30 <= 20
# X_31 + y_31 <= 28
# X_32 + y_32 <= 31
# X_33 + y_33 <= 29
# X_34 + y_34 <= 32
# X_35 + y_35 <= 28
# X_36 + y_36 <= 19
# X_37 + y_37 <= 33
# X_38 + y_38 <= 34
# X_39 + y_39 <= 29
# X_4 + y_4 <= 19
# X_40 + y_40 <= 9
# X_41 + y_41 <= 30
# X_42 + y_42 <= 13
# X_43 + y_43 <= 20
# X_44 + y_44 <= 29
# X_45 + y_45 <= 24
# X_46 + y_46 <= 21
# X_47 + y_47 <= 30
# X_48 + y_48 <= 33
# X_49 + y_49 <= 18
# X_5 + y_5 <= 31
# X_50 + y_50 <= 28
# X_51 + y_51 <= 21
# X_52 + y_52 <= 28
# X_53 + y_53 <= 30
# X_54 + y_54 <= 30
# X_55 + y_55 <= 12
# X_56 + y_56 <= 27
# X_57 + y_57 <= 34
# X_58 + y_58 <= 32
# X_59 + y_59 <= 16
# X_6 + y_6 <= 29
# X_60 + y_60 <= 17
# X_61 + y_61 <= 20
# X_62 + y_62 <= 23
# X_63 + y_63 <= 10
# X_64 + y_64 <= 11
# X_65 + y_65 <= 31
# X_66 + y_66 <= 18
# X_67 + y_67 <= 20
# X_68 + y_68 <= 33
# X_69 + y_69 <= 14
# X_7 + y_7 <= 33
# X_70 + y_70 <= 27
# X_71 + y_71 <= 30
# X_72 + y_72 <= 29
# X_73 + y_73 <= 35
# X_74 + y_74 <= 24
# X_75 + y_75 <= 27
# X_76 + y_76 <= 11
# X_77 + y_77 <= 33
# X_78 + y_78 <= 10
# X_79 + y_79 <= 29
# X_8 + y_8 <= 36
# X_80 + y_80 <= 30
# X_81 + y_81 <= 25
# X_82 + y_82 <= 35
# X_83 + y_83 <= 22
# X_84 + y_84 <= 26
# X_85 + y_85 <= 8
# X_86 + y_86 <= 26
# X_87 + y_87 <= 27
# X_88 + y_88 <= 24
# X_89 + y_89 <= 17
# X_9 + y_9 <= 31
# X_90 + y_90 <= 26
# X_91 + y_91 <= 36
# X_92 + y_92 <= 19
# X_93 + y_93 <= 27
# X_94 + y_94 <= 30
# X_95 + y_95 <= 24
# X_96 + y_96 <= 32
# X_97 + y_97 <= 32
# X_98 + y_98 <= 28
# X_99 + y_99 <= 24

# %%
model
# Out:
# Supply-infra:
# MINIMIZE
# 1*X_0 + 1*X_1 + 1*X_10 + 1*X_11 + 1*X_12 + 1*X_13 + 1*X_14 + 1*X_15 + 1*X_16 + 1*X_17 + 1*X_18 + 1*X_19 + 1*X_2 + 1*X_20 + 1*X_21 + 1*X_22 + 1*X_23 + 1*X_24 + 1*X_25 + 1*X_26 + 1*X_27 + 1*X_28 + 1*X_29 + 1*X_3 + 1*X_30 + 1*X_31 + 1*X_32 + 1*X_33 + 1*X_34 + 1*X_35 + 1*X_36 + 1*X_37 + 1*X_38 + 1*X_39 + 1*X_4 + 1*X_40 + 1*X_41 + 1*X_42 + 1*X_43 + 1*X_44 + 1*X_45 + 1*X_46 + 1*X_47 + 1*X_48 + 1*X_49 + 1*X_5 + 1*X_50 + 1*X_51 + 1*X_52 + 1*X_53 + 1*X_54 + 1*X_55 + 1*X_56 + 1*X_57 + 1*X_58 + 1*X_59 + 1*X_6 + 1*X_60 + 1*X_61 + 1*X_62 + 1*X_63 + 1*X_64 + 1*X_65 + 1*X_66 + 1*X_67 + 1*X_68 + 1*X_69 + 1*X_7 + 1*X_70 + 1*X_71 + 1*X_72 + 1*X_73 + 1*X_74 + 1*X_75 + 1*X_76 + 1*X_77 + 1*X_78 + 1*X_79 + 1*X_8 + 1*X_80 + 1*X_81 + 1*X_82 + 1*X_83 + 1*X_84 + 1*X_85 + 1*X_86 + 1*X_87 + 1*X_88 + 1*X_89 + 1*X_9 + 1*X_90 + 1*X_91 + 1*X_92 + 1*X_93 + 1*X_94 + 1*X_95 + 1*X_96 + 1*X_97 + 1*X_98 + 1*X_99 + 1.5*y_0 + 1.5*y_1 + 1.5*y_10 + 1.5*y_11 + 1.5*y_12 + 1.5*y_13 + 1.5*y_14 + 1.5*y_15 + 1.5*y_16 + 1.5*y_17 + 1.5*y_18 + 1.5*y_19 + 1.5*y_2 + 1.5*y_20 + 1.5*y_21 + 1.5*y_22 + 1.5*y_23 + 1.5*y_24 + 1.5*y_25 + 1.5*y_26 + 1.5*y_27 + 1.5*y_28 + 1.5*y_29 + 1.5*y_3 + 1.5*y_30 + 1.5*y_31 + 1.5*y_32 + 1.5*y_33 + 1.5*y_34 + 1.5*y_35 + 1.5*y_36 + 1.5*y_37 + 1.5*y_38 + 1.5*y_39 + 1.5*y_4 + 1.5*y_40 + 1.5*y_41 + 1.5*y_42 + 1.5*y_43 + 1.5*y_44 + 1.5*y_45 + 1.5*y_46 + 1.5*y_47 + 1.5*y_48 + 1.5*y_49 + 1.5*y_5 + 1.5*y_50 + 1.5*y_51 + 1.5*y_52 + 1.5*y_53 + 1.5*y_54 + 1.5*y_55 + 1.5*y_56 + 1.5*y_57 + 1.5*y_58 + 1.5*y_59 + 1.5*y_6 + 1.5*y_60 + 1.5*y_61 + 1.5*y_62 + 1.5*y_63 + 1.5*y_64 + 1.5*y_65 + 1.5*y_66 + 1.5*y_67 + 1.5*y_68 + 1.5*y_69 + 1.5*y_7 + 1.5*y_70 + 1.5*y_71 + 1.5*y_72 + 1.5*y_73 + 1.5*y_74 + 1.5*y_75 + 1.5*y_76 + 1.5*y_77 + 1.5*y_78 + 1.5*y_79 + 1.5*y_8 + 1.5*y_80 + 1.5*y_81 + 1.5*y_82 + 1.5*y_83 + 1.5*y_84 + 1.5*y_85 + 1.5*y_86 + 1.5*y_87 + 1.5*y_88 + 1.5*y_89 + 1.5*y_9 + 1.5*y_90 + 1.5*y_91 + 1.5*y_92 + 1.5*y_93 + 1.5*y_94 + 1.5*y_95 + 1.5*y_96 + 1.5*y_97 + 1.5*y_98 + 1.5*y_99 + 0.0
# SUBJECT TO
# _C1: X_0 >= 5
#
# _C2: X_1 >= 4
#
# _C3: X_10 >= 6
#
# _C4: X_11 >= 5
#
# _C5: X_12 >= 11
#
# _C6: X_13 >= 9
#
# _C7: X_14 >= 9
#
# _C8: X_15 >= 6
#
# _C9: X_16 >= 9
#
# _C10: X_17 >= 6
#
# _C11: X_18 >= 6
#
# _C12: X_19 >= 9
#
# _C13: X_2 >= 5
#
# _C14: X_20 >= 7
#
# _C15: X_21 >= 4
#
# _C16: X_22 >= 5
#
# _C17: X_23 >= 4
#
# _C18: X_24 >= 4
#
# _C19: X_25 >= 1
#
# _C20: X_26 >= 6
#
# _C21: X_27 >= 6
#
# _C22: X_28 >= 10
#
# _C23: X_29 >= 5
#
# _C24: X_3 >= 4
#
# _C25: X_30 >= 7
#
# _C26: X_31 >= 6
#
# _C27: X_32 >= 7
#
# _C28: X_33 >= 8
#
# _C29: X_34 >= 11
#
# _C30: X_35 >= 6
#
# _C31: X_36 >= 5
#
# _C32: X_37 >= 6
#
# _C33: X_38 >= 7
#
# _C34: X_39 >= 6
#
# _C35: X_4 >= 5
#
# _C36: X_40 >= 2
#
# _C37: X_41 >= 4
#
# _C38: X_42 >= 4
#
# _C39: X_43 >= 5
#
# _C40: X_44 >= 6
#
# _C41: X_45 >= 7
#
# _C42: X_46 >= 3
#
# _C43: X_47 >= 11
#
# _C44: X_48 >= 6
#
# _C45: X_49 >= 1
#
# _C46: X_5 >= 7
#
# _C47: X_50 >= 3
#
# _C48: X_51 >= 5
#
# _C49: X_52 >= 7
#
# _C50: X_53 >= 7
#
# _C51: X_54 >= 7
#
# _C52: X_55 >= 4
#
# _C53: X_56 >= 3
#
# _C54: X_57 >= 2
#
# _C55: X_58 >= 3
#
# _C56: X_59 >= 3
#
# _C57: X_6 >= 6
#
# _C58: X_60 >= 5
#
# _C59: X_61 >= 8
#
# _C60: X_62 >= 7
#
# _C61: X_63 >= 2
#
# _C62: X_64 >= 3
#
# _C63: X_65 >= 5
#
# _C64: X_66 >= 6
#
# _C65: X_67 >= 3
#
# _C66: X_68 >= 4
#
# _C67: X_69 >= 2
#
# _C68: X_7 >= 8
#
# _C69: X_70 >= 6
#
# _C70: X_71 >= 5
#
# _C71: X_72 >= 2
#
# _C72: X_73 >= 12
#
# _C73: X_74 >= 10
#
# _C74: X_75 >= 5
#
# _C75: X_76 >= 3
#
# _C76: X_77 >= 3
#
# _C77: X_78 >= 4
#
# _C78: X_79 >= 7
#
# _C79: X_8 >= 11
#
# _C80: X_80 >= 7
#
# _C81: X_81 >= 8
#
# _C82: X_82 >= 7
#
# _C83: X_83 >= 6
#
# _C84: X_84 >= 7
#
# _C85: X_85 >= 5
#
# _C86: X_86 >= 9
#
# _C87: X_87 >= 6
#
# _C88: X_88 >= 5
#
# _C89: X_89 >= 4
#
# _C90: X_9 >= 3
#
# _C91: X_90 >= 11
#
# _C92: X_91 >= 3
#
# _C93: X_92 >= 6
#
# _C94: X_93 >= 8
#
# _C95: X_94 >= 7
#
# _C96: X_95 >= 3
#
# _C97: X_96 >= 5
#
# _C98: X_97 >= 4
#
# _C99: X_98 >= 7
#
# _C100: X_99 >= 2
#
# _C101: y_0 >= 3
#
# _C102: y_1 >= 7
#
# _C103: y_10 >= 14
#
# _C104: y_11 >= 5
#
# _C105: y_12 >= 6
#
# _C106: y_13 >= 6
#
# _C107: y_14 >= 8
#
# _C108: y_15 >= 6
#
# _C109: y_16 >= 1
#
# _C110: y_17 >= 5
#
# _C111: y_18 >= 0
#
# _C112: y_19 >= 4
#
# _C113: y_2 >= 5
#
# _C114: y_20 >= 5
#
# _C115: y_21 >= 12
#
# _C116: y_22 >= 6
#
# _C117: y_23 >= 2
#
# _C118: y_24 >= 0
#
# _C119: y_25 >= 8
#
# _C120: y_26 >= 8
#
# _C121: y_27 >= 8
#
# _C122: y_28 >= 8
#
# _C123: y_29 >= 4
#
# _C124: y_3 >= 7
#
# _C125: y_30 >= 3
#
# _C126: y_31 >= 10
#
# _C127: y_32 >= 11
#
# _C128: y_33 >= 4
#
# _C129: y_34 >= 6
#
# _C130: y_35 >= 3
#
# _C131: y_36 >= 2
#
# _C132: y_37 >= 9
#
# _C133: y_38 >= 10
#
# _C134: y_39 >= 7
#
# _C135: y_4 >= 1
#
# _C136: y_40 >= 1
#
# _C137: y_41 >= 9
#
# _C138: y_42 >= 4
#
# _C139: y_43 >= 4
#
# _C140: y_44 >= 6
#
# _C141: y_45 >= 6
#
# _C142: y_46 >= 4
#
# _C143: y_47 >= 4
#
# _C144: y_48 >= 10
#
# _C145: y_49 >= 6
#
# _C146: y_5 >= 6
#
# _C147: y_50 >= 8
#
# _C148: y_51 >= 1
#
# _C149: y_52 >= 10
#
# _C150: y_53 >= 13
#
# _C151: y_54 >= 8
#
# _C152: y_55 >= 1
#
# _C153: y_56 >= 7
#
# _C154: y_57 >= 16
#
# _C155: y_58 >= 10
#
# _C156: y_59 >= 1
#
# _C157: y_6 >= 9
#
# _C158: y_60 >= 1
#
# _C159: y_61 >= 3
#
# _C160: y_62 >= 3
#
# _C161: y_63 >= 3
#
# _C162: y_64 >= 0
#
# _C163: y_65 >= 10
#
# _C164: y_66 >= 5
#
# _C165: y_67 >= 2
#
# _C166: y_68 >= 11
#
# _C167: y_69 >= 2
#
# _C168: y_7 >= 13
#
# _C169: y_70 >= 9
#
# _C170: y_71 >= 6
#
# _C171: y_72 >= 8
#
# _C172: y_73 >= 7
#
# _C173: y_74 >= 1
#
# _C174: y_75 >= 4
#
# _C175: y_76 >= 1
#
# _C176: y_77 >= 15
#
# _C177: y_78 >= 2
#
# _C178: y_79 >= 11
#
# _C179: y_8 >= 8
#
# _C180: y_80 >= 6
#
# _C181: y_81 >= 9
#
# _C182: y_82 >= 7
#
# _C183: y_83 >= 7
#
# _C184: y_84 >= 6
#
# _C185: y_85 >= 2
#
# _C186: y_86 >= 7
#
# _C187: y_87 >= 7
#
# _C188: y_88 >= 5
#
# _C189: y_89 >= 1
#
# _C190: y_9 >= 10
#
# _C191: y_90 >= 5
#
# _C192: y_91 >= 12
#
# _C193: y_92 >= 3
#
# _C194: y_93 >= 6
#
# _C195: y_94 >= 9
#
# _C196: y_95 >= 4
#
# _C197: y_96 >= 10
#
# _C198: y_97 >= 14
#
# _C199: y_98 >= 5
#
# _C200: y_99 >= 11
#
# _C201: 200 X_0 + 400 y_0 = 2800
#
# _C202: 200 X_1 + 400 y_1 = 4200
#
# _C203: 200 X_10 + 400 y_10 = 2000
#
# _C204: 200 X_11 + 400 y_11 = 2200
#
# _C205: 200 X_12 + 400 y_12 = 600
#
# _C206: 200 X_13 + 400 y_13 = 800
#
# _C207: 200 X_14 + 400 y_14 = 4200
#
# _C208: 200 X_15 + 400 y_15 = 4400
#
# _C209: 200 X_16 + 400 y_16 = 6000
#
# _C210: 200 X_17 + 400 y_17 = 5800
#
# _C211: 200 X_18 + 400 y_18 = 8800
#
# _C212: 200 X_19 + 400 y_19 = 3000
#
# _C213: 200 X_2 + 400 y_2 = 9000
#
# _C214: 200 X_20 + 400 y_20 = 5200
#
# _C215: 200 X_21 + 400 y_21 = 5200
#
# _C216: 200 X_22 + 400 y_22 = 9400
#
# _C217: 200 X_23 + 400 y_23 = 5000
#
# _C218: 200 X_24 + 400 y_24 = 2800
#
# _C219: 200 X_25 + 400 y_25 = 5400
#
# _C220: 200 X_26 + 400 y_26 = 1400
#
# _C221: 200 X_27 + 400 y_27 = 1600
#
# _C222: 200 X_28 + 400 y_28 = 1400
#
# _C223: 200 X_29 + 400 y_29 = 4800
#
# _C224: 200 X_3 + 400 y_3 = 1200
#
# _C225: 200 X_30 + 400 y_30 = 1600
#
# _C226: 200 X_31 + 400 y_31 = 2600
#
# _C227: 200 X_32 + 400 y_32 = 9600
#
# _C228: 200 X_33 + 400 y_33 = 4400
#
# _C229: 200 X_34 + 400 y_34 = 2200
#
# _C230: 200 X_35 + 400 y_35 = 7400
#
# _C231: 200 X_36 + 400 y_36 = 2600
#
# _C232: 200 X_37 + 400 y_37 = 3000
#
# _C233: 200 X_38 + 400 y_38 = 2800
#
# _C234: 200 X_39 + 400 y_39 = 5000
#
# _C235: 200 X_4 + 400 y_4 = 7600
#
# _C236: 200 X_40 + 400 y_40 = 5000
#
# _C237: 200 X_41 + 400 y_41 = 2400
#
# _C238: 200 X_42 + 400 y_42 = 17200
#
# _C239: 200 X_43 + 400 y_43 = 2000
#
# _C240: 200 X_44 + 400 y_44 = 5200
#
# _C241: 200 X_45 + 400 y_45 = 2800
#
# _C242: 200 X_46 + 400 y_46 = 4800
#
# _C243: 200 X_47 + 400 y_47 = 7200
#
# _C244: 200 X_48 + 400 y_48 = 3200
#
# _C245: 200 X_49 + 400 y_49 = 2400
#
# _C246: 200 X_5 + 400 y_5 = 4600
#
# _C247: 200 X_50 + 400 y_50 = 3000
#
# _C248: 200 X_51 + 400 y_51 = 3200
#
# _C249: 200 X_52 + 400 y_52 = 2600
#
# _C250: 200 X_53 + 400 y_53 = 4400
#
# _C251: 200 X_54 + 400 y_54 = 11000
#
# _C252: 200 X_55 + 400 y_55 = 1000
#
# _C253: 200 X_56 + 400 y_56 = 1200
#
# _C254: 200 X_57 + 400 y_57 = 3600
#
# _C255: 200 X_58 + 400 y_58 = 4000
#
# _C256: 200 X_59 + 400 y_59 = 1000
#
# _C257: 200 X_6 + 400 y_6 = 1600
#
# _C258: 200 X_60 + 400 y_60 = 600
#
# _C259: 200 X_61 + 400 y_61 = 800
#
# _C260: 200 X_62 + 400 y_62 = 400
#
# _C261: 200 X_63 + 400 y_63 = 600
#
# _C262: 200 X_64 + 400 y_64 = 200
#
# _C263: 200 X_65 + 400 y_65 = 1400
#
# _C264: 200 X_66 + 400 y_66 = 1000
#
# _C265: 200 X_67 + 400 y_67 = 4800
#
# _C266: 200 X_68 + 400 y_68 = 9400
#
# _C267: 200 X_69 + 400 y_69 = 7400
#
# _C268: 200 X_7 + 400 y_7 = 5400
#
# _C269: 200 X_70 + 400 y_70 = 3600
#
# _C270: 200 X_71 + 400 y_71 = 8600
#
# _C271: 200 X_72 + 400 y_72 = 2400
#
# _C272: 200 X_73 + 400 y_73 = 2400
#
# _C273: 200 X_74 + 400 y_74 = 3200
#
# _C274: 200 X_75 + 400 y_75 = 2000
#
# _C275: 200 X_76 + 400 y_76 = 5400
#
# _C276: 200 X_77 + 400 y_77 = 3800
#
# _C277: 200 X_78 + 400 y_78 = 8000
#
# _C278: 200 X_79 + 400 y_79 = 1800
#
# _C279: 200 X_8 + 400 y_8 = 6000
#
# _C280: 200 X_80 + 400 y_80 = 8200
#
# _C281: 200 X_81 + 400 y_81 = 1400
#
# _C282: 200 X_82 + 400 y_82 = 11800
#
# _C283: 200 X_83 + 400 y_83 = 4600
#
# _C284: 200 X_84 + 400 y_84 = 3000
#
# _C285: 200 X_85 + 400 y_85 = 1600
#
# _C286: 200 X_86 + 400 y_86 = 4200
#
# _C287: 200 X_87 + 400 y_87 = 6200
#
# _C288: 200 X_88 + 400 y_88 = 3800
#
# _C289: 200 X_89 + 400 y_89 = 3400
#
# _C290: 200 X_9 + 400 y_9 = 3000
#
# _C291: 200 X_90 + 400 y_90 = 9600
#
# _C292: 200 X_91 + 400 y_91 = 3400
#
# _C293: 200 X_92 + 400 y_92 = 10800
#
# _C294: 200 X_93 + 400 y_93 = 2800
#
# _C295: 200 X_94 + 400 y_94 = 6600
#
# _C296: 200 X_95 + 400 y_95 = 4600
#
# _C297: 200 X_96 + 400 y_96 = 9000
#
# _C298: 200 X_97 + 400 y_97 = 6800
#
# _C299: 200 X_98 + 400 y_98 = 2800
#
# _C300: 200 X_99 + 400 y_99 = 1000
#
# _C301: X_0 + y_0 <= 23
#
# _C302: X_1 + y_1 <= 27
#
# _C303: X_10 + y_10 <= 31
#
# _C304: X_11 + y_11 <= 26
#
# _C305: X_12 + y_12 <= 32
#
# _C306: X_13 + y_13 <= 28
#
# _C307: X_14 + y_14 <= 25
#
# _C308: X_15 + y_15 <= 32
#
# _C309: X_16 + y_16 <= 30
#
# _C310: X_17 + y_17 <= 21
#
# _C311: X_18 + y_18 <= 14
#
# _C312: X_19 + y_19 <= 21
#
# _C313: X_2 + y_2 <= 22
#
# _C314: X_20 + y_20 <= 28
#
# _C315: X_21 + y_21 <= 30
#
# _C316: X_22 + y_22 <= 24
#
# _C317: X_23 + y_23 <= 13
#
# _C318: X_24 + y_24 <= 7
#
# _C319: X_25 + y_25 <= 26
#
# _C320: X_26 + y_26 <= 28
#
# _C321: X_27 + y_27 <= 23
#
# _C322: X_28 + y_28 <= 28
#
# _C323: X_29 + y_29 <= 20
#
# _C324: X_3 + y_3 <= 24
#
# _C325: X_30 + y_30 <= 20
#
# _C326: X_31 + y_31 <= 28
#
# _C327: X_32 + y_32 <= 31
#
# _C328: X_33 + y_33 <= 29
#
# _C329: X_34 + y_34 <= 32
#
# _C330: X_35 + y_35 <= 28
#
# _C331: X_36 + y_36 <= 19
#
# _C332: X_37 + y_37 <= 33
#
# _C333: X_38 + y_38 <= 34
#
# _C334: X_39 + y_39 <= 29
#
# _C335: X_4 + y_4 <= 19
#
# _C336: X_40 + y_40 <= 9
#
# _C337: X_41 + y_41 <= 30
#
# _C338: X_42 + y_42 <= 13
#
# _C339: X_43 + y_43 <= 20
#
# _C340: X_44 + y_44 <= 29
#
# _C341: X_45 + y_45 <= 24
#
# _C342: X_46 + y_46 <= 21
#
# _C343: X_47 + y_47 <= 30
#
# _C344: X_48 + y_48 <= 33
#
# _C345: X_49 + y_49 <= 18
#
# _C346: X_5 + y_5 <= 31
#
# _C347: X_50 + y_50 <= 28
#
# _C348: X_51 + y_51 <= 21
#
# _C349: X_52 + y_52 <= 28
#
# _C350: X_53 + y_53 <= 30
#
# _C351: X_54 + y_54 <= 30
#
# _C352: X_55 + y_55 <= 12
#
# _C353: X_56 + y_56 <= 27
#
# _C354: X_57 + y_57 <= 34
#
# _C355: X_58 + y_58 <= 32
#
# _C356: X_59 + y_59 <= 16
#
# _C357: X_6 + y_6 <= 29
#
# _C358: X_60 + y_60 <= 17
#
# _C359: X_61 + y_61 <= 20
#
# _C360: X_62 + y_62 <= 23
#
# _C361: X_63 + y_63 <= 10
#
# _C362: X_64 + y_64 <= 11
#
# _C363: X_65 + y_65 <= 31
#
# _C364: X_66 + y_66 <= 18
#
# _C365: X_67 + y_67 <= 20
#
# _C366: X_68 + y_68 <= 33
#
# _C367: X_69 + y_69 <= 14
#
# _C368: X_7 + y_7 <= 33
#
# _C369: X_70 + y_70 <= 27
#
# _C370: X_71 + y_71 <= 30
#
# _C371: X_72 + y_72 <= 29
#
# _C372: X_73 + y_73 <= 35
#
# _C373: X_74 + y_74 <= 24
#
# _C374: X_75 + y_75 <= 27
#
# _C375: X_76 + y_76 <= 11
#
# _C376: X_77 + y_77 <= 33
#
# _C377: X_78 + y_78 <= 10
#
# _C378: X_79 + y_79 <= 29
#
# _C379: X_8 + y_8 <= 36
#
# _C380: X_80 + y_80 <= 30
#
# _C381: X_81 + y_81 <= 25
#
# _C382: X_82 + y_82 <= 35
#
# _C383: X_83 + y_83 <= 22
#
# _C384: X_84 + y_84 <= 26
#
# _C385: X_85 + y_85 <= 8
#
# _C386: X_86 + y_86 <= 26
#
# _C387: X_87 + y_87 <= 27
#
# _C388: X_88 + y_88 <= 24
#
# _C389: X_89 + y_89 <= 17
#
# _C390: X_9 + y_9 <= 31
#
# _C391: X_90 + y_90 <= 26
#
# _C392: X_91 + y_91 <= 36
#
# _C393: X_92 + y_92 <= 19
#
# _C394: X_93 + y_93 <= 27
#
# _C395: X_94 + y_94 <= 30
#
# _C396: X_95 + y_95 <= 24
#
# _C397: X_96 + y_96 <= 32
#
# _C398: X_97 + y_97 <= 32
#
# _C399: X_98 + y_98 <= 28
#
# _C400: X_99 + y_99 <= 24
#
# VARIABLES
# 5 <= X_0 Integer
# 4 <= X_1 Integer
# 6 <= X_10 Integer
# 5 <= X_11 Integer
# 11 <= X_12 Integer
# 9 <= X_13 Integer
# 9 <= X_14 Integer
# 6 <= X_15 Integer
# 9 <= X_16 Integer
# 6 <= X_17 Integer
# 6 <= X_18 Integer
# 9 <= X_19 Integer
# 5 <= X_2 Integer
# 7 <= X_20 Integer
# 4 <= X_21 Integer
# 5 <= X_22 Integer
# 4 <= X_23 Integer
# 4 <= X_24 Integer
# 1 <= X_25 Integer
# 6 <= X_26 Integer
# 6 <= X_27 Integer
# 10 <= X_28 Integer
# 5 <= X_29 Integer
# 4 <= X_3 Integer
# 7 <= X_30 Integer
# 6 <= X_31 Integer
# 7 <= X_32 Integer
# 8 <= X_33 Integer
# 11 <= X_34 Integer
# 6 <= X_35 Integer
# 5 <= X_36 Integer
# 6 <= X_37 Integer
# 7 <= X_38 Integer
# 6 <= X_39 Integer
# 5 <= X_4 Integer
# 2 <= X_40 Integer
# 4 <= X_41 Integer
# 4 <= X_42 Integer
# 5 <= X_43 Integer
# 6 <= X_44 Integer
# 7 <= X_45 Integer
# 3 <= X_46 Integer
# 11 <= X_47 Integer
# 6 <= X_48 Integer
# 1 <= X_49 Integer
# 7 <= X_5 Integer
# 3 <= X_50 Integer
# 5 <= X_51 Integer
# 7 <= X_52 Integer
# 7 <= X_53 Integer
# 7 <= X_54 Integer
# 4 <= X_55 Integer
# 3 <= X_56 Integer
# 2 <= X_57 Integer
# 3 <= X_58 Integer
# 3 <= X_59 Integer
# 6 <= X_6 Integer
# 5 <= X_60 Integer
# 8 <= X_61 Integer
# 7 <= X_62 Integer
# 2 <= X_63 Integer
# 3 <= X_64 Integer
# 5 <= X_65 Integer
# 6 <= X_66 Integer
# 3 <= X_67 Integer
# 4 <= X_68 Integer
# 2 <= X_69 Integer
# 8 <= X_7 Integer
# 6 <= X_70 Integer
# 5 <= X_71 Integer
# 2 <= X_72 Integer
# 12 <= X_73 Integer
# 10 <= X_74 Integer
# 5 <= X_75 Integer
# 3 <= X_76 Integer
# 3 <= X_77 Integer
# 4 <= X_78 Integer
# 7 <= X_79 Integer
# 11 <= X_8 Integer
# 7 <= X_80 Integer
# 8 <= X_81 Integer
# 7 <= X_82 Integer
# 6 <= X_83 Integer
# 7 <= X_84 Integer
# 5 <= X_85 Integer
# 9 <= X_86 Integer
# 6 <= X_87 Integer
# 5 <= X_88 Integer
# 4 <= X_89 Integer
# 3 <= X_9 Integer
# 11 <= X_90 Integer
# 3 <= X_91 Integer
# 6 <= X_92 Integer
# 8 <= X_93 Integer
# 7 <= X_94 Integer
# 3 <= X_95 Integer
# 5 <= X_96 Integer
# 4 <= X_97 Integer
# 7 <= X_98 Integer
# 2 <= X_99 Integer
# 3 <= y_0 Integer
# 7 <= y_1 Integer
# 14 <= y_10 Integer
# 5 <= y_11 Integer
# 6 <= y_12 Integer
# 6 <= y_13 Integer
# 8 <= y_14 Integer
# 6 <= y_15 Integer
# 1 <= y_16 Integer
# 5 <= y_17 Integer
# 0 <= y_18 Integer
# 4 <= y_19 Integer
# 5 <= y_2 Integer
# 5 <= y_20 Integer
# 12 <= y_21 Integer
# 6 <= y_22 Integer
# 2 <= y_23 Integer
# 0 <= y_24 Integer
# 8 <= y_25 Integer
# 8 <= y_26 Integer
# 8 <= y_27 Integer
# 8 <= y_28 Integer
# 4 <= y_29 Integer
# 7 <= y_3 Integer
# 3 <= y_30 Integer
# 10 <= y_31 Integer
# 11 <= y_32 Integer
# 4 <= y_33 Integer
# 6 <= y_34 Integer
# 3 <= y_35 Integer
# 2 <= y_36 Integer
# 9 <= y_37 Integer
# 10 <= y_38 Integer
# 7 <= y_39 Integer
# 1 <= y_4 Integer
# 1 <= y_40 Integer
# 9 <= y_41 Integer
# 4 <= y_42 Integer
# 4 <= y_43 Integer
# 6 <= y_44 Integer
# 6 <= y_45 Integer
# 4 <= y_46 Integer
# 4 <= y_47 Integer
# 10 <= y_48 Integer
# 6 <= y_49 Integer
# 6 <= y_5 Integer
# 8 <= y_50 Integer
# 1 <= y_51 Integer
# 10 <= y_52 Integer
# 13 <= y_53 Integer
# 8 <= y_54 Integer
# 1 <= y_55 Integer
# 7 <= y_56 Integer
# 16 <= y_57 Integer
# 10 <= y_58 Integer
# 1 <= y_59 Integer
# 9 <= y_6 Integer
# 1 <= y_60 Integer
# 3 <= y_61 Integer
# 3 <= y_62 Integer
# 3 <= y_63 Integer
# 0 <= y_64 Integer
# 10 <= y_65 Integer
# 5 <= y_66 Integer
# 2 <= y_67 Integer
# 11 <= y_68 Integer
# 2 <= y_69 Integer
# 13 <= y_7 Integer
# 9 <= y_70 Integer
# 6 <= y_71 Integer
# 8 <= y_72 Integer
# 7 <= y_73 Integer
# 1 <= y_74 Integer
# 4 <= y_75 Integer
# 1 <= y_76 Integer
# 15 <= y_77 Integer
# 2 <= y_78 Integer
# 11 <= y_79 Integer
# 8 <= y_8 Integer
# 6 <= y_80 Integer
# 9 <= y_81 Integer
# 7 <= y_82 Integer
# 7 <= y_83 Integer
# 6 <= y_84 Integer
# 2 <= y_85 Integer
# 7 <= y_86 Integer
# 7 <= y_87 Integer
# 5 <= y_88 Integer
# 1 <= y_89 Integer
# 10 <= y_9 Integer
# 5 <= y_90 Integer
# 12 <= y_91 Integer
# 3 <= y_92 Integer
# 6 <= y_93 Integer
# 9 <= y_94 Integer
# 4 <= y_95 Integer
# 10 <= y_96 Integer
# 14 <= y_97 Integer
# 5 <= y_98 Integer
# 11 <= y_99 Integer

# %%
model.solve(PULP_CBC_CMD())
status =  LpStatus[model.status]
print(status)
# Out:
# Infeasible

# %%
print("Total Cost:", model.objective.value())
# Out:
# Total Cost: 1554.0

# %%
model.objective.value()*600
# Out:
# 932400.0

# %%
# DSij Variable's value
for v in model.variables():
    print(v.name,"=", v.value())
# Out:
# X_0 = 5.0
# X_1 = 4.0
# X_10 = 6.0
# X_11 = 5.0
# X_12 = 11.0
# X_13 = 9.0
# X_14 = 9.0
# X_15 = 6.0
# X_16 = 9.0
# X_17 = 6.0
# X_18 = 6.0
# X_19 = 9.0
# X_2 = 5.0
# X_20 = 7.0
# X_21 = 4.0
# X_22 = 5.0
# X_23 = 4.0
# X_24 = 4.0
# X_25 = 1.0
# X_26 = 6.0
# X_27 = 6.0
# X_28 = 10.0
# X_29 = 5.0
# X_3 = 4.0
# X_30 = 7.0
# X_31 = 6.0
# X_32 = 7.0
# X_33 = 8.0
# X_34 = 11.0
# X_35 = 6.0
# X_36 = 5.0
# X_37 = 6.0
# X_38 = 7.0
# X_39 = 6.0
# X_4 = 5.0
# X_40 = 2.0
# X_41 = 4.0
# X_42 = 4.0
# X_43 = 5.0
# X_44 = 6.0
# X_45 = 7.0
# X_46 = 3.0
# X_47 = 11.0
# X_48 = 6.0
# X_49 = 1.0
# X_5 = 7.0
# X_50 = 3.0
# X_51 = 5.0
# X_52 = 7.0
# X_53 = 7.0
# X_54 = 7.0
# X_55 = 4.0
# X_56 = 3.0
# X_57 = 2.0
# X_58 = 3.0
# X_59 = 3.0
# X_6 = 6.0
# X_60 = 5.0
# X_61 = 8.0
# X_62 = 7.0
# X_63 = 2.0
# X_64 = 3.0
# X_65 = 5.0
# X_66 = 6.0
# X_67 = 3.0
# X_68 = 4.0
# X_69 = 2.0
# X_7 = 8.0
# X_70 = 6.0
# X_71 = 5.0
# X_72 = 2.0
# X_73 = 12.0
# X_74 = 10.0
# X_75 = 5.0
# X_76 = 3.0
# X_77 = 3.0
# X_78 = 4.0
# X_79 = 7.0
# X_8 = 11.0
# X_80 = 7.0
# X_81 = 8.0
# X_82 = 7.0
# X_83 = 6.0
# X_84 = 7.0
# X_85 = 5.0
# X_86 = 9.0
# X_87 = 6.0
# X_88 = 5.0
# X_89 = 4.0
# X_9 = 3.0
# X_90 = 11.0
# X_91 = 3.0
# X_92 = 6.0
# X_93 = 8.0
# X_94 = 7.0
# X_95 = 3.0
# X_96 = 5.0
# X_97 = 4.0
# X_98 = 7.0
# X_99 = 2.0
# y_0 = 3.0
# y_1 = 7.0
# y_10 = 14.0
# y_11 = 5.0
# y_12 = 6.0
# y_13 = 6.0
# y_14 = 8.0
# y_15 = 6.0
# y_16 = 1.0
# y_17 = 5.0
# y_18 = 0.0
# y_19 = 4.0
# y_2 = 5.0
# y_20 = 5.0
# y_21 = 12.0
# y_22 = 6.0
# y_23 = 2.0
# y_24 = 0.0
# y_25 = 8.0
# y_26 = 8.0
# y_27 = 8.0
# y_28 = 8.0
# y_29 = 4.0
# y_3 = 7.0
# y_30 = 3.0
# y_31 = 10.0
# y_32 = 11.0
# y_33 = 4.0
# y_34 = 6.0
# y_35 = 3.0
# y_36 = 2.0
# y_37 = 9.0
# y_38 = 10.0
# y_39 = 7.0
# y_4 = 1.0
# y_40 = 1.0
# y_41 = 9.0
# y_42 = 41.0
# y_43 = 4.0
# y_44 = 6.0
# y_45 = 6.0
# y_46 = 4.0
# y_47 = 4.0
# y_48 = 10.0
# y_49 = 6.0
# y_5 = 6.0
# y_50 = 8.0
# y_51 = 1.0
# y_52 = 10.0
# y_53 = 13.0
# y_54 = 8.0
# y_55 = 1.0
# y_56 = 7.0
# y_57 = 16.0
# y_58 = 10.0
# y_59 = 1.0
# y_6 = 9.0
# y_60 = 1.0
# y_61 = 3.0
# y_62 = 3.0
# y_63 = 3.0
# y_64 = 0.0
# y_65 = 10.0
# y_66 = 5.0
# y_67 = 2.0
# y_68 = 11.0
# y_69 = 2.0
# y_7 = 13.0
# y_70 = 9.0
# y_71 = 6.0
# y_72 = 8.0
# y_73 = 7.0
# y_74 = 1.0
# y_75 = 4.0
# y_76 = 1.0
# y_77 = 15.0
# y_78 = 2.0
# y_79 = 11.0
# y_8 = 8.0
# y_80 = 6.0
# y_81 = 9.0
# y_82 = 7.0
# y_83 = 7.0
# y_84 = 6.0
# y_85 = 2.0
# y_86 = 7.0
# y_87 = 7.0
# y_88 = 5.0
# y_89 = 1.0
# y_9 = 10.0
# y_90 = 5.0
# y_91 = 12.0
# y_92 = 3.0
# y_93 = 6.0
# y_94 = 9.0
# y_95 = 4.0
# y_96 = 10.0
# y_97 = 14.0
# y_98 = 5.0
# y_99 = 11.0

# %%
p=0
lst=[]
x_var_r=[]
y_var_r=[]
for v in model.variables():
    k=v.value()
    lst.append(int(k))
for i in range(n_supply):
    x_var_r.append(lst[p])
    p+=1
for i in range(n_supply):
    y_var_r.append(lst[p])
    p+=1
x_var_r=np.array(x_var_r)
y_var_r=np.array(y_var_r)
print(x_var_r)
print(y_var_r)
# Out:
# [ 5  4  6  5 11  9  9  6  9  6  6  9  5  7  4  5  4  4  1  6  6 10  5  4
#   7  6  7  8 11  6  5  6  7  6  5  2  4  4  5  6  7  3 11  6  1  7  3  5
#   7  7  7  4  3  2  3  3  6  5  8  7  2  3  5  6  3  4  2  8  6  5  2 12
#  10  5  3  3  4  7 11  7  8  7  6  7  5  9  6  5  4  3 11  3  6  8  7  3
#   5  4  7  2]
# [ 3  7 14  5  6  6  8  6  1  5  0  4  5  5 12  6  2  0  8  8  8  8  4  7
#   3 10 11  4  6  3  2  9 10  7  1  1  9 41  4  6  6  4  4 10  6  6  8  1
#  10 13  8  1  7 16 10  1  9  1  3  3  3  0 10  5  2 11  2 13  9  6  8  7
#   1  4  1 15  2 11  8  6  9  7  7  6  2  7  7  5  1 10  5 12  3  6  9  4
#  10 14  5 11]

# %%
infra_set.drop(infra_set.columns[infra_set.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
infra_set
# Out:
#     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0                    0     50.163110     19.412014                   23
# 1                    1     37.336451     58.119225                   27
# 2                    2     46.709232     57.525650                   31
# 3                    3     30.528626     55.379835                   26
# 4                    4     51.521781     35.116755                   32
# ..                 ...           ...           ...                  ...
# 95                  95     45.471204     20.999414                   24
# 96                  96     30.318396     33.388335                   32
# 97                  97     36.218839     22.235766                   32
# 98                  98     42.936915     38.122442                   28
# 99                  99     19.590263      3.830284                   24
#
#     existing_num_SCS  existing_num_FCS  smax18  smax19  newsmax19
# 0                  5                 3    2200    2689       2800
# 1                  4                 7    3600    4127       4200
# 2                  6                14    6800    1968       2000
# 3                  5                 5    3000    2126       2200
# 4                 11                 6    4600     566        600
# ..               ...               ...     ...     ...        ...
# 95                 3                 4    2200    4470       4600
# 96                 5                10    5000    8844       9000
# 97                 4                14    6400    6716       6800
# 98                 7                 5    3400    2796       2800
# 99                 2                11    4800     962       1000
#
# [100 rows x 9 columns]

# %%
infra_set['SCS_19']=x_var_r
infra_set['FCS_19']=y_var_r

# %%
infra_set
# Out:
#     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0                    0     50.163110     19.412014                   23
# 1                    1     37.336451     58.119225                   27
# 2                    2     46.709232     57.525650                   31
# 3                    3     30.528626     55.379835                   26
# 4                    4     51.521781     35.116755                   32
# ..                 ...           ...           ...                  ...
# 95                  95     45.471204     20.999414                   24
# 96                  96     30.318396     33.388335                   32
# 97                  97     36.218839     22.235766                   32
# 98                  98     42.936915     38.122442                   28
# 99                  99     19.590263      3.830284                   24
#
#     existing_num_SCS  existing_num_FCS  smax18  smax19  newsmax19  SCS_19  \
# 0                  5                 3    2200    2689       2800       5
# 1                  4                 7    3600    4127       4200       4
# 2                  6                14    6800    1968       2000       6
# 3                  5                 5    3000    2126       2200       5
# 4                 11                 6    4600     566        600      11
# ..               ...               ...     ...     ...        ...     ...
# 95                 3                 4    2200    4470       4600       3
# 96                 5                10    5000    8844       9000       5
# 97                 4                14    6400    6716       6800       4
# 98                 7                 5    3400    2796       2800       7
# 99                 2                11    4800     962       1000       2
#
#     FCS_19
# 0        3
# 1        7
# 2       14
# 3        5
# 4        6
# ..     ...
# 95       4
# 96      10
# 97      14
# 98       5
# 99      11
#
# [100 rows x 11 columns]

# %% [markdown]
# infra_set.to_excel('optinfra.xlsx')
