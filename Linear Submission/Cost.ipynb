# %%
import pandas as pd
import numpy as np

# %%
infra = pd.read_csv('exisiting_EV_infrastructure_2018.csv')
dsij = pd.read_excel('SampleDSij.xlsx')

# %%
infra
# Out:
#     supply_point_index  x_coordinate  y_coordinate  total_parking_slots  \
# 0                    0     50.163110     19.412014                   23
# 1                    1     37.336451     58.119225                   27
# 2                    2     46.709232     57.525650                   31
# 3                    3     30.528626     55.379835                   26
# 4                    4     51.521781     35.116755                   32
# ..                 ...           ...           ...                  ...
# 95                  95     45.471204     20.999414                   24
# 96                  96     30.318396     33.388335                   32
# 97                  97     36.218839     22.235766                   32
# 98                  98     42.936915     38.122442                   28
# 99                  99     19.590263      3.830284                   24
#
#     existing_num_SCS  existing_num_FCS
# 0                  5                 3
# ...

# %%
Cif=(infra['existing_num_SCS']+1.5*infra['existing_num_FCS'])

# %%
Cif=sum(Cif)

# %%
Cif=600*Cif
Cif
# Out:
# 899100.0

# %%
dist=pd.read_csv('Distance_Matrix.csv')

# %%
dist
# Out:
#             0          1          2          3          4          5  \
# 0   53.142156  52.208836  51.278030  50.349877  49.424527  48.502141
# 1   68.387858  67.854449  67.331667  66.819761  66.318983  65.829588
# 2   73.397670  72.772244  72.155256  71.546925  70.947474  70.357129
# 3   62.558091  62.084277  61.623049  61.174692  60.739490  60.317729
# 4   61.656645  60.831721  60.012122  59.198068  58.389791  57.587534
# ..        ...        ...        ...        ...        ...        ...
# 95  49.423023  48.514871  47.610402  46.709827  45.813377  44.921299
# 96  44.393460  43.728052  43.075582  42.436646  41.811866  41.201885
# 97  41.812426  40.961461  40.117373  39.280605  38.451635  37.630979
# 98  56.712784  55.968438  55.232167  54.504297  53.785171  53.075143
# 99  19.378569  18.394249  17.411716  16.431292  15.453376  14.478477
#
#             6          7          8          9  ...       4086       4087  \
# ...

# %%
dsij.drop(['Unnamed: 0'],inplace=True, axis=1)

# %%
dsij
# Out:
#         0         1         2         3         4         5         6     \
# 0   0.000000  0.000000  0.000000  0.000000  1.051542  0.000000  0.000000
# 1   0.003268  0.045750  0.003489  0.002387  0.000000  0.000000  0.000000
# 2   0.079191  0.003699  0.015845  0.000000  0.011560  0.015262  0.005923
# 3   0.000000  0.000000  0.000000  0.001891  0.002406  0.000000  0.000000
# 4   0.000000  0.013828  0.000000  0.000000  0.008159  0.000000  0.000000
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 96  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 97  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 98  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 99  0.000000  5.922989  1.403211  4.715261  0.732488  7.602602  0.000000
#
#         7         8         9     ...      4086      4087     4088      4089  \
# ...

# %%
dist=dist.to_numpy()
dsij=dsij.to_numpy()
sum = 0
for i in range(100):
    for j in range(4096):
        sum+=dist[i][j]*dsij[i][j]
sum
# Out:
# 8051361.417637134

# %%
Ccd=sum

# %%
Total=Ccd+Cif

# %%
Total
# Out:
# 8950461.417637134
