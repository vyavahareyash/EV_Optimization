# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
demand_set=pd.read_csv('Demand_History.csv')

# %%
demand_set.head(3001)
# Out:
#       demand_point_index  x_coordinate  y_coordinate      2010       2011  \
# 0                      0           0.5           0.5  0.352242   0.667932
# 1                      1           1.5           0.5  0.325940   0.591964
# 2                      2           2.5           0.5  0.373752   0.591890
# 3                      3           3.5           0.5  0.420686   0.584055
# 4                      4           4.5           0.5  0.475621   0.647940
# ...                  ...           ...           ...       ...        ...
# 2996                2996          52.5          46.5  4.625235  12.143628
# 2997                2997          53.5          46.5  5.545604  12.060494
# 2998                2998          54.5          46.5  4.529727  10.072652
# 2999                2999          55.5          46.5  4.999517  10.839404
# 3000                3000          56.5          46.5  5.566502  10.820340
#
#            2012       2013       2014        2015        2016        2017  \
# ...

# %%
X = np.array([[2010],[2011],[2012],[2013],[2014],[2015],[2016],[2017],[2018]])
X
# Out:
# array([[2010],
#        [2011],
#        [2012],
#        [2013],
#        [2014],
#        [2015],
#        [2016],
#        [2017],
#        [2018]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_reg3=PolynomialFeatures(degree=3)

x_poly_3=poly_reg3.fit_transform(X)

# %%
x_poly_3
# Out:
# array([[1.00000000e+00, 2.01000000e+03, 4.04010000e+06, 8.12060100e+09],
#        [1.00000000e+00, 2.01100000e+03, 4.04412100e+06, 8.13272733e+09],
#        [1.00000000e+00, 2.01200000e+03, 4.04814400e+06, 8.14486573e+09],
#        [1.00000000e+00, 2.01300000e+03, 4.05216900e+06, 8.15701620e+09],
#        [1.00000000e+00, 2.01400000e+03, 4.05619600e+06, 8.16917874e+09],
#        [1.00000000e+00, 2.01500000e+03, 4.06022500e+06, 8.18135338e+09],
#        [1.00000000e+00, 2.01600000e+03, 4.06425600e+06, 8.19354010e+09],
#        [1.00000000e+00, 2.01700000e+03, 4.06828900e+06, 8.20573891e+09],
#        [1.00000000e+00, 2.01800000e+03, 4.07232400e+06, 8.21794983e+09]])

# %%
ncol1=[]
ncol2=[]
for i in range(4096):
    y = demand_set.iloc[i,3:].values
    lin_reg_3=LinearRegression()
    lin_reg_3.fit(x_poly_3,y)
    ans1=lin_reg_3.predict(poly_reg3.transform([[2019]]))
    ans2=lin_reg_3.predict(poly_reg3.transform([[2020]]))
    ncol1.append(ans1[0])
    ncol2.append(ans2[0])

# %%
demand_set['2019']=ncol1
demand_set['2020']=ncol2

# %%
demand_set
# Out:
#       demand_point_index  x_coordinate  y_coordinate      2010      2011  \
# 0                      0           0.5           0.5  0.352242  0.667932
# 1                      1           1.5           0.5  0.325940  0.591964
# 2                      2           2.5           0.5  0.373752  0.591890
# 3                      3           3.5           0.5  0.420686  0.584055
# 4                      4           4.5           0.5  0.475621  0.647940
# ...                  ...           ...           ...       ...       ...
# 4091                4091          59.5          63.5  0.171015  0.334565
# 4092                4092          60.5          63.5  0.041716  0.061741
# 4093                4093          61.5          63.5  0.100895  0.180352
# 4094                4094          62.5          63.5  0.155353  0.290825
# 4095                4095          63.5          63.5  0.209372  0.340185
#
#           2012      2013      2014      2015      2016       2017       2018  \
# ...

# %%
#demand_set.to_excel('Prediction.xlsx')

# %%
arr=demand_set['2018']>demand_set['2019']

# %%
un,co=np.unique(arr,return_counts=True)

# %%
un
# Out:
# array([False,  True])

# %%
co
# Out:
# array([4007,   89], dtype=int64)

# %%
sum(arr)
# Out:
# 89

# %%
arr_i=[]
for i in range(4096):
    if arr[i]==True:
        arr_i.append(i)
arr_i
# Out:
# [255,
#  674,
#  747,
#  803,
#  827,
#  991,
#  1151,
#  1299,
#  1327,
#  1423,
#  1429,
#  1496,
#  1914,
#  2070,
#  2078,
#  2079,
#  2142,
#  2154,
#  2298,
#  2394,
#  2395,
#  2457,
#  2458,
#  2466,
#  2467,
#  2521,
#  2522,
#  2523,
#  2527,
#  2532,
#  2533,
#  2585,
#  2589,
#  2591,
#  2594,
#  2649,
#  2654,
#  2656,
#  2659,
#  2721,
#  2783,
#  2846,
#  2848,
#  2912,
#  3037,
#  3038,
#  3070,
#  3098,
#  3101,
#  3159,
#  3160,
#  3161,
#  3166,
#  3176,
#  3177,
#  3290,
#  3344,
#  3353,
#  3356,
#  3367,
#  3598,
#  3615,
#  3618,
#  3679,
#  3680,
#  3742,
#  3745,
#  3806,
#  3807,
#  3808,
#  3810,
#  3812,
#  3870,
#  3872,
#  3877,
#  3934,
#  3935,
#  3941,
#  3948,
#  3999,
#  4005,
#  4006,
#  4013,
#  4014,
#  4015,
#  4063,
#  4069,
#  4070,
#  4078]

# %%
len(arr_i)
# Out:
# 89
